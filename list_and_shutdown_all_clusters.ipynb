# %% [markdown]
# # List your clusters, then shut them all down

# %%
from dask_gateway import Gateway
from dask.distributed import Client
gateway = Gateway()

# %% [markdown]
# ## List clusters

# %%
gateway.list_clusters()
# Out:
# [ClusterReport<name=daskhub.5f9755e706cb40a5ac38beded77fd362, status=RUNNING>,
#  ClusterReport<name=daskhub.38c5ba77c4b04642a7313024b418ef91, status=RUNNING>]

# %% [markdown]
# ## Shut them all down

# %%
for cluster in gateway.list_clusters():
    gateway.stop_cluster(cluster_name=cluster.name)
    print(f'stopped {cluster.name}')
# Out:
# stopped daskhub.5f9755e706cb40a5ac38beded77fd362
# stopped daskhub.38c5ba77c4b04642a7313024b418ef91

# %%
gateway.list_clusters()
# Out:
# []
